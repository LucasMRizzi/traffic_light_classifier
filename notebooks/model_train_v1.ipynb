# %% [markdown]
# # Verifing GPU / Yolo

# %%
# !nvidia-smi
# Out:
# Fri Oct 31 12:13:00 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.03                 Driver Version: 566.03         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1050 Ti   WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   58C    P0             N/A /  120W |    1682MiB /   4096MiB |      2%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ^C

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source="https://ultralytics.com/images/bus.jpg"

# %% [markdown]
# # Custom Data Training

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=data/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
